# %%
import pandas as pd

# %%
df = pd.read_excel("/content/WorldBank.xlsx")
df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# ...

# %%
# Perform data cleaning (remove duplicates, handle missing values).
df = df.drop_duplicates()
df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 15 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  12449 non-null  object
#  1   Country Code                                                  12449 non-null  object
#  2   Region                                                        12449 non-null  object
#  3   IncomeGroup                                                   12449 non-null  object
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          11440 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          11416 non-null  float64
# ...

# %%
mean_df = df['Population density (people per sq. km of land area)'].mean()
mean_df
# Out:
# 318.8613704823554

# %%
# Replace Na values with mean
df = df.fillna(df.mean(numeric_only=True))
df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                 28.643276
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 15 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  12449 non-null  object
#  1   Country Code                                                  12449 non-null  object
#  2   Region                                                        12449 non-null  object
#  3   IncomeGroup                                                   12449 non-null  object
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          12449 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          12449 non-null  float64
# ...

# %%
df
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 0      Afghanistan          AFG          South Asia  Low income  2018
# 1      Afghanistan          AFG          South Asia  Low income  2017
# 2      Afghanistan          AFG          South Asia  Low income  2016
# 3      Afghanistan          AFG          South Asia  Low income  2015
# 4      Afghanistan          AFG          South Asia  Low income  2014
# ...            ...          ...                 ...         ...   ...
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                 28.643276
# ...

# %%
Year_filter = df[df['Year']<2014]
Year_filter['Year']
# Out:
# 5        2013
# 6        2012
# 7        2011
# 8        2010
# 9        2009
#          ...
# 12444    1964
# 12445    1963
# 12446    1962
# 12447    1961
# 12448    1960
# Name: Year, Length: 11394, dtype: int64

# %%
# Group By colum
group_df = df.groupby('Region')
group_df.count()
# Out:
#                             Country Name  Country Code  IncomeGroup  Year  \
# Region
# East Asia & Pacific                 2006          2006         2006  2006
# Europe & Central Asia               3304          3304         3304  3304
# Latin America & Caribbean           2419          2419         2419  2419
# Middle East & North Africa          1239          1239         1239  1239
# North America                        177           177          177   177
# South Asia                           472           472          472   472
# Sub-Saharan Africa                  2832          2832         2832  2832
#
#                             Birth rate, crude (per 1,000 people)  \
# Region
# East Asia & Pacific                                         2006
# Europe & Central Asia                                       3304
# Latin America & Caribbean                                   2419
# Middle East & North Africa                                  1239
# ...

# %%
groupby_country = df.groupby(df['Country Name'])
groupby_country.count()
# Out:
#                        Country Code  Region  IncomeGroup  Year  \
# Country Name
# Afghanistan                      59      59           59    59
# Albania                          59      59           59    59
# Algeria                          59      59           59    59
# American Samoa                   59      59           59    59
# Andorra                          59      59           59    59
# ...                             ...     ...          ...   ...
# Virgin Islands (U.S.)            59      59           59    59
# West Bank and Gaza               59      59           59    59
# Yemen, Rep.                      59      59           59    59
# Zambia                           59      59           59    59
# Zimbabwe                         59      59           59    59
#
#                        Birth rate, crude (per 1,000 people)  \
# Country Name
# Afghanistan                                              59
# ...

# %%
groupby_incom = df.groupby('IncomeGroup')
groupby_incom.describe()
# Out:
#                         Year                                             \
#                        count    mean        std     min     25%     50%
# IncomeGroup
# High income: OECD     1888.0  1989.0  17.033898  1960.0  1974.0  1989.0
# High income: nonOECD  2773.0  1989.0  17.032458  1960.0  1974.0  1989.0
# Low income            1829.0  1989.0  17.034044  1960.0  1974.0  1989.0
# Lower middle income   2832.0  1989.0  17.032394  1960.0  1974.0  1989.0
# Upper middle income   3127.0  1989.0  17.032110  1960.0  1974.0  1989.0
#
#                                      Birth rate, crude (per 1,000 people)  \
#                          75%     max                                count
# IncomeGroup
# High income: OECD     2004.0  2018.0                               1888.0
# High income: nonOECD  2004.0  2018.0                               2773.0
# Low income            2004.0  2018.0                               1829.0
# ...
